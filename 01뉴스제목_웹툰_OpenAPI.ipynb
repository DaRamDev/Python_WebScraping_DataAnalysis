# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.3
# bs4 버전 = 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url,headers=req_header)
print(res.status_code, res.ok)
# 응답(response)이 OK 이면
if res.ok:    
    # 응답 (response)에서 text 추출
    html = res.text
    # BeautifulSoup 객체 생성  
    soup = BeautifulSoup(html,'html.parser')
    #print(soup)
    # CSS 선택자
    # print(soup.select("div.sa_text a[href*='mnews/article']"))
    print(len(soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")))
    a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
    print(type(a_tags))
    # <a> 태그 리스트 순회하기    
    for a_tag in a_tags:    
        title = a_tag.text.strip()  #<a>title</a>
        link = a_tag['href']        #<a href="link">title</a>
        print(title, link)
# 응답(response)이 Error 이면 status code 출력    
else:
    print(f'Error Code = {res.status_code}')
# Out:
# https://news.naver.com/section/105
# 200 True
# 88
# <class 'bs4.element.ResultSet'>
# 아스트라 출시 연기…오픈 AI “안전운영 시간 걸려” https://n.news.naver.com/mnews/article/025/0003543237
#  https://n.news.naver.com/mnews/article/comment/025/0003543237
# 48세부터 고혈압·당뇨·흡연 잡으면 치매 13년 늦게 온다 https://n.news.naver.com/mnews/article/081/0003668832
#  https://n.news.naver.com/mnews/article/comment/081/0003668832
# 포스코DX, 장애인 유튜브 크리에이터 육성 지원…공모전 개최 https://n.news.naver.com/mnews/article/001/0016241716
#  https://n.news.naver.com/mnews/article/comment/001/0016241716
# 제2 우주센터 유치전…전남광주 vs 제주특별도 https://n.news.naver.com/mnews/article/056/0012234231
#  https://n.news.naver.com/mnews/article/comment/056/0012234231
# 폴드8, ‘남성·중장년폰’ 이미지 깼다…1030·여심까지 저격 https://n.news.naver.com/mnews/article/003/0014116903
#  https://n.news.naver.com/mnews/article/comment/003/0014116903
# LG유플·브로드컴, 공유기서 AI 직접 구동…홈 네트워크 자동 복구 실증 https://n.news.naver.com/mnews/article/018/0006347893
#  https://n.news.naver.com/mnews/article/comment/018/0006347893
# 이놈의 인기…맨날 나만 모기 물리는 이유 있었다 https://n.news.naver.com/mnews/article/015/0005318961
#  https://n.news.naver.com/mnews/article/comment/081/0003668838
# 모노리식3D 특허공세...美ITC, SK하이닉스 2번째 특허침해조사 착수 https://n.news.naver.com/mnews/article/092/0002433432
#  https://n.news.naver.com/mnews/article/comment/092/0002433432
# 반도체, 이젠 5년짜리 계약이 뉴노멀인 까닭은 https://n.news.naver.com/mnews/article/023/0003992083
#  https://n.news.naver.com/mnews/article/comment/023/0003992083
# 소변 몇 방울로 10초면 끝… 1000원대 ‘마약 검사키트’ 나온다 https://n.news.naver.com/mnews/article/020/0003739602
#  https://n.news.naver.com/mnews/article/comment/020/0003739602
# 부모에게 물려받은 유전자 첫 해독… ‘내 유전체 지도’ 시대 개막 https://n.news.naver.com/mnews/article/020/0003739599
#  https://n.news.naver.com/mnews/article/comment/020/0003739599
# 통신3사 성장엔진 재편…'AI 데이터센터' 존재감 커진다 https://n.news.naver.com/mnews/article/629/0000522924
#  https://n.news.naver.com/mnews/article/comment/629/0000522924
# 삼프로TV서 개인정보 유출…계좌·카드 등 46만여 건 추산 https://n.news.naver.com/mnews/article/119/0003119990
#  https://n.news.naver.com/mnews/article/comment/119/0003119990

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':100,'경제':101,'사회':102,'생활/문화':103,'세계':104,'IT/과학':105}

def print_news(section_name):  #print_new('생활/문화') 
    sid = section_dict.get(section_name,'102')
    url = f'https://news.naver.com/section/{sid}'
    print(f'{section_name} 뉴스 {url}')

    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
    }

    # requests 의 get() 함수 호출하기 
    res = requests.get(url,headers=req_header)
    # 응답(response)이 OK 이면
    if res.ok:    
        # 응답 (response)에서 text 추출
        html = res.text
        # BeautifulSoup 객체 생성  
        soup = BeautifulSoup(html,'html.parser')
        # CSS 선택자
        a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
        # <a> 태그 리스트 순회하기    
        for a_tag in a_tags:    
            title = a_tag.text.strip()  #<a>title</a>
            link = a_tag['href']        #<a href="link">title</a>
            print(title, link)
    # 응답(response)이 Error 이면 status code 출력    
    else:
        print(f'Error Code = {res.status_code}')

# %%
print_news('경제')
# Out:
# 경제 뉴스 https://news.naver.com/section/101
# “내가 괜히 국장 돌아와서 고생”…서학개미, 두 달 만에 다시 美주식 순매수 https://n.news.naver.com/mnews/article/009/0005718733
#  https://n.news.naver.com/mnews/article/comment/009/0005718733
# CU, 편의점 헬스케어 2.0 실행…건기식 점포 2000여점 추가 https://n.news.naver.com/mnews/article/050/0000109492
#  https://n.news.naver.com/mnews/article/comment/050/0000109492
# 양구군청, 직원 차량 5부제 시범운영…민원인 주차환경 개선 https://n.news.naver.com/mnews/article/001/0016240683
#  https://n.news.naver.com/mnews/article/comment/001/0016240683
# 슈퍼컴퓨터부터 전력망까지…협력 확대하는 한·아세안 https://n.news.naver.com/mnews/article/422/0000894066
#  https://n.news.naver.com/mnews/article/comment/422/0000894066
# [코인뉴스] ETF에 모처럼 훈풍…비트코인은 ‘글쎄’ https://n.news.naver.com/mnews/article/119/0003120058
#  https://n.news.naver.com/mnews/article/comment/119/0003120058
# 코스피 출발 직후 6300 회복…美 금리 긴장완화 훈풍 https://n.news.naver.com/mnews/article/008/0005397604
#  https://n.news.naver.com/mnews/article/comment/008/0005397604
# LX세미콘, 현대차·기아 첫 국산 차량용 MCU 양산 https://n.news.naver.com/mnews/article/421/0009105142
#  https://n.news.naver.com/mnews/article/comment/421/0009105142
# '9.8→200조' 역대급 호조에 10배 이상 '껑충'…'확신의 매수 구간' 파격 전망 https://n.news.naver.com/mnews/article/215/0001261736
#  https://n.news.naver.com/mnews/article/comment/215/0001261736
# 美 고용 쇼크에 약달러…달러·원 환율 1410원선 거래 https://n.news.naver.com/mnews/article/421/0009105139
#  https://n.news.naver.com/mnews/article/comment/421/0009105139
# "LIG디펜스앤에어로스페이스, 130만원 간다" 증권가 전망에 급등 https://n.news.naver.com/mnews/article/008/0005397603
#  https://n.news.naver.com/mnews/article/comment/008/0005397603
# 삼전닉스 다시 살 때?…모건스탠리 "메모리주 재진입 기회" https://n.news.naver.com/mnews/article/448/0000632503
#  https://n.news.naver.com/mnews/article/comment/448/0000632503
# 비상경영 체제인데…삼성전자 DX노조, 11조 무리한 요구 '논란' https://n.news.naver.com/mnews/article/421/0009105136
#  https://n.news.naver.com/mnews/article/comment/421/0009105136
# 15억~20억 아파트 '최고가' 속출…수도권 다시 불붙었다 https://n.news.naver.com/mnews/article/629/0000522966
#  https://n.news.naver.com/mnews/article/comment/629/0000522966
# NH證 "다시 천스닥 간다…정책 효과에 힘입어 상승" https://n.news.naver.com/mnews/article/421/0009105134
#  https://n.news.naver.com/mnews/article/comment/421/0009105134

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=812354&no=208&week=sun',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg'
]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers=req_header)
    print(res.status_code)        
    # binary 응답 데이터 가져오기
    img_data = res.content
    print(type(img_data))    
    # url에서 파일명만 추출하기
    file_name = os.path.basename(img_url)
    print(file_name)    
    # binday data를 file에 write하기
    with open(file_name,'wb') as file:
        print(f'Writing to {file_name}({len(img_data):,} bytes)')
        file.write(img_data)
# Out:
# 200
# <class 'bytes'>
# 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg(124,462 bytes)
# 200
# <class 'bytes'>
# 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg(141,956 bytes)
# 200
# <class 'bytes'>
# 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg(170,913 bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=812354&no=208&week=sun'

req_header = {
    'referer': webtoon_url,
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

res = requests.get(webtoon_url, headers=req_header)
if res.ok:
    soup = BeautifulSoup(res.text,'html.parser')    
    print(len(soup.select("img[src$='.jpg']")))
    print(len(soup.select("img[src*='IMAG01']")))
    #ResultSet 객체
    img_tags = soup.select("img[src*='IMAG01']")
    # for img_tag in img_tags:
        # img_tag는 Tag 객체
        # print(img_tag['src'])
        # img_url_list = [] #list()

    # 기존방식
    img_url_list = []   #['',''] 
    for img_tag in img_tags:
        img_url_list.append(img_tag['src'])
    print(img_url_list[:2])
    # Pythonic 방식 - List Comprehension 
    img_url_list2 = [img_tag['src'] for img_tag in img_tags]
    print(img_url_list2[:2])

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
# Out:
# 200

# %% [markdown]
# ### .env 파일에서 환경변수 읽어오기
# * CLIENT_ID와 CLIENT_SECRET 환경변수 읽어오기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * [네이버개발자가이드](https://developers.naver.com/docs/utils/captcha/examples/)
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# ### 5-1. 블로그 검색하기
# * 네이버 개발자센터에서 제공하는 검색 API 사용하기

# %%
import requests
from pprint import pprint

headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)

# json() 함수로 응답 결과 가져오기 [{},{},{}]
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'
print(len(res.json()['items'])) 
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %% [markdown]
# ### 5-2. 블로그 검색하기
# * 네이버 API HUB (NAVER Cloud)에서 제공하는 검색 API 사용하기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %%
import requests
from pprint import pprint

headers = {
    'X-NCP-APIGW-API-KEY-ID': CLIENT_ID,
    'X-NCP-APIGW-API-KEY': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}
domain_url = 'https://naverapihub.apigw.ntruss.com'
url = f'{domain_url}/search/v1/blog'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기 [{},{},{}]
print(len(res.json()['items'])) 
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %%
# data/blog.json 파일 생성하기
import json

with open('data/blog.json','w', encoding='utf-8') as file:
    json.dump(items_data, file)
